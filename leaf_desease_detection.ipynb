# %% [markdown]
# <a href="https://colab.research.google.com/github/shivam8415/my1repo/blob/main/leaf_desease_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YTH5tCpKUJgUnmqwnxT1")
project = rf.workspace("shivam-ky6lx").project("plantdoc-lacmj")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#   Using cached roboflow-1.2.9-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
# Using cached roboflow-1.2.9-py3-none-any.whl (88 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(data='PlantDoc-1/data.yaml', epochs = 100 , batch = 16)
# Out:
# Ultralytics 8.3.202 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model.predict(source="/content/PlantDoc-1/test/images", save=True , stream = True)

for result in results:
  pass
# Out:
# image 1/246 /content/PlantDoc-1/test/images/-2320-Bacterial-Spot-and-Speck_jpg.rf.12c2113c35373b51cb93878bfc87cf85.jpg: 480x640 1 Tomato Septoria leaf spot, 41.8ms
# image 2/246 /content/PlantDoc-1/test/images/0000_jpg.rf.cc268255bc3f350b795edc7258bb2d6c.jpg: 640x640 1 grape leaf, 9.6ms
# image 3/246 /content/PlantDoc-1/test/images/000_jpg.rf.2f1d4196b68f75eb4d718ce9e3fbcebb.jpg: 480x640 1 Tomato leaf bacterial spot, 10.7ms
# image 4/246 /content/PlantDoc-1/test/images/00_jpg.rf.c369b285371c1fe07d4efc4edaaf033f.jpg: 480x640 1 Bell_pepper leaf, 1 Bell_pepper leaf spot, 6.0ms
# image 5/246 /content/PlantDoc-1/test/images/00pe_jpg.rf.d6eef81f4b800ab2278a72c41306d25a.jpg: 640x480 1 Apple leaf, 37.7ms
# image 6/246 /content/PlantDoc-1/test/images/01_jpg.rf.2336589adaec076bfee027173070164c.jpg: 512x640 1 Bell_pepper leaf spot, 39.1ms
# image 7/246 /content/PlantDoc-1/test/images/02_-Rust-2017-207u24s_jpg.rf.073b76a369ad9f4291d280634e3f90c6.jpg: 384x640 (no detections), 38.9ms
# ...

# %%
from tensorflow.keras.models import load_model
model.save('/content/drive/MyDrive/saved model/alreadytrained.h5')
